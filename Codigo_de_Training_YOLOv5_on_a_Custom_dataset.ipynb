# %%
#clone YOLOv5 and 
# !git clone https://github.com/ultralytics/yolov5  # clone repo
# %cd yolov5
# %pip install -qr requirements.txt # install dependencies
# %pip install -q roboflow

import torch
import os
from IPython.display import Image, clear_output  # to display images

print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 14483, done.
# remote: Counting objects: 100% (37/37), done.
# remote: Compressing objects: 100% (28/28), done.
# remote: Total 14483 (delta 16), reused 28 (delta 9), pack-reused 14446
# Receiving objects: 100% (14483/14483), 13.52 MiB | 25.55 MiB/s, done.
# Resolving deltas: 100% (9987/9987), done.
# /content/yolov5
#      |████████████████████████████████| 1.6 MB 4.8 MB/s
#      |████████████████████████████████| 41 kB 205 kB/s
#      |████████████████████████████████| 138 kB 7.8 MB/s
#      |████████████████████████████████| 54 kB 353 kB/s
#      |████████████████████████████████| 67 kB 7.2 MB/s
#      |████████████████████████████████| 178 kB 49.8 MB/s
#      |████████████████████████████████| 145 kB 55.6 MB/s
#      |████████████████████████████████| 62 kB 1.7 MB/s
#   Building wheel for wget (setup.py) ... done
# Setup complete. Using torch 1.12.1+cu113 (Tesla T4)

# %%
# !pip install joblib
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (1.2.0)

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="8ZCgxk8Dp4WDfKHzTqNG")
project = rf.workspace("cesar-school-jtqzc").project("projeto-deteccao")
dataset = project.version(1).download("yolov5")
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: roboflow in /usr/local/lib/python3.7/dist-packages (0.2.18)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.7/dist-packages (from roboflow) (6.0)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.7/dist-packages (from roboflow) (1.21.6)
# Requirement already satisfied: urllib3==1.26.6 in /usr/local/lib/python3.7/dist-packages (from roboflow) (1.26.6)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.7/dist-packages (from roboflow) (0.21.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from roboflow) (2.28.1)
# Requirement already satisfied: opencv-python-headless>=4.5.1.48 in /usr/local/lib/python3.7/dist-packages (from roboflow) (4.6.0.66)
# Requirement already satisfied: glob2 in /usr/local/lib/python3.7/dist-packages (from roboflow) (0.7)
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.7/dist-packages (from roboflow) (7.1.2)
# Requirement already satisfied: cycler==0.10.0 in /usr/local/lib/python3.7/dist-packages (from roboflow) (0.10.0)
# Requirement already satisfied: requests-toolbelt in /usr/local/lib/python3.7/dist-packages (from roboflow) (0.10.1)
# Requirement already satisfied: chardet==4.0.0 in /usr/local/lib/python3.7/dist-packages (from roboflow) (4.0.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from roboflow) (2.8.2)
# Requirement already satisfied: idna==2.10 in /usr/local/lib/python3.7/dist-packages (from roboflow) (2.10)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.7/dist-packages (from roboflow) (1.4.4)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from roboflow) (1.15.0)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.7/dist-packages (from roboflow) (4.64.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.7/dist-packages (from roboflow) (3.2.2)
# Requirement already satisfied: wget in /usr/local/lib/python3.7/dist-packages (from roboflow) (3.2)
# Requirement already satisfied: certifi==2021.5.30 in /usr/local/lib/python3.7/dist-packages (from roboflow) (2021.5.30)
# Requirement already satisfied: pyparsing==2.4.7 in /usr/local/lib/python3.7/dist-packages (from roboflow) (2.4.7)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from kiwisolver>=1.3.1->roboflow) (4.1.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/lib/python3.7/dist-packages (from requests->roboflow) (2.1.1)
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in Projeto-Detecção--1 to yolov5pytorch: 100% [38067701 / 38067701] bytes
# Extracting Dataset Version Zip to Projeto-Detecção--1 in yolov5pytorch:: 100%|██████████| 1660/1660 [00:01<00:00, 1436.95it/s]

# %%
from google.colab import drive

drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %%
# !python train.py --img 640 --batch 64 --epochs 100 --data {dataset.location}/data.yaml --weights yolov5s.pt --cache
# Out:
# train: weights=yolov5s.pt, cfg=, data=/content/yolov5/Projeto-Detecção--1/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=100, batch_size=64, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.2-226-gfde7758 Python-3.7.15 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# ClearML: run 'pip install clearml' to automatically track, visualize and remotely train YOLOv5 🚀 in ClearML
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLOv5 🚀 runs in Comet
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# Downloading https://ultralytics.com/assets/Arial.ttf to /root/.config/Ultralytics/Arial.ttf...
# 100% 755k/755k [00:00<00:00, 4.47MB/s]
# Downloading https://github.com/ultralytics/yolov5/releases/download/v6.2/yolov5s.pt to yolov5s.pt...
# 100% 14.1M/14.1M [00:00<00:00, 34.1MB/s]
#
# Overriding model.yaml nc=80 with nc=4
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Conv                      [3, 32, 6, 2, 2]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  2    115712  models.common.C3                        [128, 128, 2]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1   1182720  models.common.C3                        [512, 512, 1]
#   9                -1  1    656896  models.common.SPPF                      [512, 512, 5]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1     24273  models.yolo.Detect                      [4, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# Model summary: 214 layers, 7030417 parameters, 7030417 gradients, 16.0 GFLOPs
#
# Transferred 343/349 items from yolov5s.pt
# AMP: checks passed ✅
# optimizer: SGD(lr=0.01) with parameter groups 57 weight(decay=0.0), 60 weight(decay=0.0005), 60 bias
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# train: Scanning '/content/yolov5/Projeto-Detecção--1/train/labels' images and labels...718 found, 0 missing, 0 empty, 0 corrupt: 100% 718/718 [00:00<00:00, 1999.98it/s]
# train: New cache created: /content/yolov5/Projeto-Detecção--1/train/labels.cache
# train: Caching images (0.8GB ram): 100% 718/718 [00:03<00:00, 192.10it/s]
# val: Scanning '/content/yolov5/Projeto-Detecção--1/valid/labels' images and labels...102 found, 0 missing, 0 empty, 0 corrupt: 100% 102/102 [00:00<00:00, 1001.00it/s]
# val: New cache created: /content/yolov5/Projeto-Detecção--1/valid/labels.cache
# val: Caching images (0.1GB ram): 100% 102/102 [00:01<00:00, 71.02it/s]
#
# AutoAnchor: 2.24 anchors/target, 1.000 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Plotting labels to runs/train/exp/labels.jpg...
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to runs/train/exp
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        0/99      14.1G     0.1151    0.03174    0.04983         55        640: 100% 12/12 [00:12<00:00,  1.08s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:04<00:00,  4.47s/it]
#                    all        102        116    0.00105      0.244    0.00407   0.000816
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        1/99      12.6G    0.08147    0.03145    0.04173         42        640: 100% 12/12 [00:08<00:00,  1.42it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:02<00:00,  2.27s/it]
#                    all        102        116      0.605      0.118      0.289      0.123
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        2/99      12.6G    0.06641    0.02785    0.03104         42        640: 100% 12/12 [00:08<00:00,  1.41it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.82s/it]
#                    all        102        116      0.335      0.562      0.434      0.224
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        3/99      12.6G     0.0605    0.02299    0.02634         41        640: 100% 12/12 [00:08<00:00,  1.42it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.85s/it]
#                    all        102        116      0.431      0.449      0.411        0.2
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        4/99      12.6G    0.05537    0.02192    0.01893         40        640: 100% 12/12 [00:08<00:00,  1.42it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.84s/it]
#                    all        102        116      0.469      0.593      0.612      0.331
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        5/99      12.6G    0.05594     0.0196    0.01838         46        640: 100% 12/12 [00:08<00:00,  1.42it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.46s/it]
#                    all        102        116      0.316      0.342      0.325      0.145
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        6/99      12.6G    0.05671    0.01955    0.01692         46        640: 100% 12/12 [00:08<00:00,  1.39it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.34s/it]
#                    all        102        116       0.12      0.121      0.102     0.0414
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        7/99      12.6G    0.05215    0.01951    0.01688         36        640: 100% 12/12 [00:08<00:00,  1.40it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.46s/it]
#                    all        102        116      0.204       0.12     0.0809     0.0257
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        8/99      12.6G    0.05462    0.01964    0.01799         47        640: 100% 12/12 [00:08<00:00,  1.41it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.42s/it]
#                    all        102        116      0.429      0.414      0.343      0.155
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        9/99      12.6G    0.05371    0.02098    0.01774         48        640: 100% 12/12 [00:08<00:00,  1.40it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.53s/it]
#                    all        102        116       0.12       0.13     0.0464     0.0113
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       10/99      12.6G    0.05211    0.01999    0.02013         46        640: 100% 12/12 [00:08<00:00,  1.37it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.44s/it]
#                    all        102        116     0.0723      0.131     0.0537     0.0159
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       11/99      12.6G     0.0452    0.02019    0.01688         55        640: 100% 12/12 [00:08<00:00,  1.41it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.39s/it]
#                    all        102        116      0.319      0.218      0.112     0.0393
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       12/99      12.6G    0.05435    0.01944    0.01469         39        640: 100% 12/12 [00:08<00:00,  1.38it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.54s/it]
#                    all        102        116     0.0785      0.239     0.0747     0.0241
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       13/99      12.6G    0.05436    0.01947    0.01484         38        640: 100% 12/12 [00:08<00:00,  1.39it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.60s/it]
#                    all        102        116      0.197       0.23      0.144     0.0391
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       14/99      12.6G    0.04532    0.01905    0.01296         46        640: 100% 12/12 [00:08<00:00,  1.38it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.50s/it]
#                    all        102        116      0.338      0.277      0.238     0.0776
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       15/99      12.6G    0.05023      0.019    0.01315         36        640: 100% 12/12 [00:08<00:00,  1.37it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.44s/it]
#                    all        102        116      0.488      0.471      0.442      0.222
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       16/99      12.6G    0.04685    0.01808    0.01816         37        640: 100% 12/12 [00:08<00:00,  1.38it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.51s/it]
#                    all        102        116      0.385       0.59      0.479      0.224
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       17/99      12.6G    0.04533    0.01946    0.01345         45        640: 100% 12/12 [00:08<00:00,  1.37it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.61s/it]
#                    all        102        116      0.595      0.467      0.414      0.169
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       18/99      12.6G    0.04628    0.01914    0.01352         54        640: 100% 12/12 [00:08<00:00,  1.39it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.41s/it]
#                    all        102        116       0.45      0.529      0.475      0.174
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       19/99      12.6G    0.04767    0.01872    0.01523         43        640: 100% 12/12 [00:08<00:00,  1.38it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.40s/it]
#                    all        102        116      0.496      0.523      0.481      0.207
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       20/99      12.6G    0.04342    0.01818    0.01251         44        640: 100% 12/12 [00:08<00:00,  1.37it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.45s/it]
#                    all        102        116      0.591       0.59      0.556      0.269
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       21/99      12.6G    0.04151    0.01899    0.01005         53        640: 100% 12/12 [00:08<00:00,  1.36it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.45s/it]
#                    all        102        116      0.625      0.653      0.692      0.373
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       22/99      12.6G    0.04344    0.01777   0.009694         49        640: 100% 12/12 [00:08<00:00,  1.39it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.45s/it]
#                    all        102        116      0.528      0.524      0.515      0.226
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       23/99      12.6G    0.03644    0.01762   0.009553         48        640: 100% 12/12 [00:08<00:00,  1.40it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.69s/it]
#                    all        102        116      0.694      0.678      0.676      0.313
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       24/99      12.6G    0.03884    0.01727    0.00893         47        640: 100% 12/12 [00:08<00:00,  1.37it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.50s/it]
#                    all        102        116      0.763      0.667      0.752      0.365
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       25/99      12.6G     0.0422     0.0177   0.009845         43        640: 100% 12/12 [00:08<00:00,  1.40it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.65s/it]
#                    all        102        116      0.674      0.556      0.656      0.329
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       26/99      12.6G    0.04075    0.01748   0.008333         46        640: 100% 12/12 [00:08<00:00,  1.35it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.62s/it]
#                    all        102        116      0.597      0.549      0.616      0.299
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       27/99      12.6G    0.03953     0.0174    0.00926         48        640: 100% 12/12 [00:08<00:00,  1.36it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.41s/it]
#                    all        102        116      0.749      0.736      0.712      0.373
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       28/99      12.6G    0.03813    0.01722    0.01173         51        640: 100% 12/12 [00:08<00:00,  1.37it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.59s/it]
#                    all        102        116       0.72      0.667      0.703      0.365
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       29/99      12.6G    0.03755    0.01681   0.006934         42        640: 100% 12/12 [00:08<00:00,  1.38it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.48s/it]
#                    all        102        116      0.727      0.679      0.668      0.348
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       30/99      12.6G    0.04007    0.01637     0.0106         52        640: 100% 12/12 [00:08<00:00,  1.37it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.42s/it]
#                    all        102        116      0.689      0.652      0.661      0.334
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       31/99      12.6G    0.03795    0.01706   0.009299         55        640: 100% 12/12 [00:08<00:00,  1.36it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.34s/it]
#                    all        102        116      0.607      0.452      0.499      0.268
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       32/99      12.6G    0.03794    0.01698   0.008583         45        640: 100% 12/12 [00:08<00:00,  1.38it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.49s/it]
#                    all        102        116      0.721      0.657      0.747      0.385
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       33/99      12.6G    0.03677    0.01649   0.006893         42        640: 100% 12/12 [00:08<00:00,  1.37it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.45s/it]
#                    all        102        116      0.743      0.715      0.751      0.366
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       34/99      12.6G     0.0396    0.01586   0.006994         50        640: 100% 12/12 [00:08<00:00,  1.35it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.49s/it]
#                    all        102        116      0.813      0.735      0.763      0.413
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       35/99      12.6G    0.03404    0.01597   0.007105         42        640: 100% 12/12 [00:08<00:00,  1.37it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.43s/it]
#                    all        102        116      0.669      0.727       0.76       0.46
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       36/99      12.6G    0.03494    0.01743   0.007174         47        640: 100% 12/12 [00:08<00:00,  1.37it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.49s/it]
#                    all        102        116      0.812      0.804      0.826      0.424
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       37/99      12.6G    0.03455    0.01495   0.009238         30        640: 100% 12/12 [00:08<00:00,  1.38it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.54s/it]
#                    all        102        116      0.789      0.769       0.83      0.453
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       38/99      12.6G    0.03395    0.01634    0.01027         45        640: 100% 12/12 [00:08<00:00,  1.34it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.38s/it]
#                    all        102        116      0.608      0.633      0.632      0.348
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       39/99      12.6G    0.03494    0.01597    0.01016         43        640: 100% 12/12 [00:08<00:00,  1.35it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.65s/it]
#                    all        102        116      0.861      0.742       0.85       0.48
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       40/99      12.6G    0.03608    0.01557   0.006999         45        640: 100% 12/12 [00:08<00:00,  1.35it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.48s/it]
#                    all        102        116      0.814      0.768      0.806      0.475
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       41/99      12.6G    0.03964     0.0169   0.007807         52        640: 100% 12/12 [00:08<00:00,  1.37it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.61s/it]
#                    all        102        116      0.729      0.726      0.716      0.386
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       42/99      12.6G    0.03913    0.01588   0.005731         52        640: 100% 12/12 [00:08<00:00,  1.39it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.62s/it]
#                    all        102        116      0.837       0.79      0.804      0.408
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       43/99      12.6G    0.03458    0.01564    0.00773         43        640: 100% 12/12 [00:08<00:00,  1.36it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.63s/it]
#                    all        102        116      0.795      0.781      0.795      0.438
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       44/99      12.6G    0.03698    0.01626   0.007458         45        640: 100% 12/12 [00:08<00:00,  1.37it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.41s/it]
#                    all        102        116      0.781      0.748      0.774      0.366
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       45/99      12.6G    0.03566     0.0156   0.005906         39        640: 100% 12/12 [00:08<00:00,  1.34it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.48s/it]
#                    all        102        116       0.83      0.816       0.81      0.449
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       46/99      12.6G    0.03466    0.01522   0.006223         46        640: 100% 12/12 [00:08<00:00,  1.36it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.37s/it]
#                    all        102        116      0.774      0.769      0.806      0.418
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       47/99      12.6G     0.0352    0.01558   0.008182         47        640: 100% 12/12 [00:08<00:00,  1.36it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.50s/it]
#                    all        102        116      0.812      0.806      0.849      0.476
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       48/99      12.6G     0.0309    0.01513   0.005604         45        640: 100% 12/12 [00:08<00:00,  1.38it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.58s/it]
#                    all        102        116      0.833       0.79      0.826      0.423
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       49/99      12.6G    0.03202    0.01466   0.005836         38        640: 100% 12/12 [00:08<00:00,  1.36it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.50s/it]
#                    all        102        116      0.801      0.792       0.82      0.496
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       50/99      12.6G    0.03359    0.01579   0.008936         50        640: 100% 12/12 [00:08<00:00,  1.34it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.49s/it]
#                    all        102        116      0.783      0.653      0.724      0.391
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       51/99      12.6G     0.0338    0.01543    0.00749         43        640: 100% 12/12 [00:08<00:00,  1.35it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.51s/it]
#                    all        102        116      0.798      0.742      0.822      0.455
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       52/99      12.6G    0.03158    0.01463   0.006276         37        640: 100% 12/12 [00:08<00:00,  1.37it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.50s/it]
#                    all        102        116      0.855      0.735      0.805      0.416
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       53/99      12.6G    0.03176    0.01481   0.006412         38        640: 100% 12/12 [00:08<00:00,  1.35it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.63s/it]
#                    all        102        116      0.879      0.792      0.871      0.523
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       54/99      12.6G     0.0309     0.0145   0.005346         44        640: 100% 12/12 [00:08<00:00,  1.36it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.43s/it]
#                    all        102        116      0.795      0.833      0.831      0.447
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       55/99      12.6G    0.03403     0.0146   0.005823         50        640: 100% 12/12 [00:08<00:00,  1.36it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.44s/it]
#                    all        102        116      0.818      0.828      0.863      0.488
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       56/99      12.6G    0.03634     0.0143   0.005964         41        640: 100% 12/12 [00:08<00:00,  1.36it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.54s/it]
#                    all        102        116      0.769      0.879      0.859      0.474
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       57/99      12.6G    0.03522    0.01429   0.003993         50        640: 100% 12/12 [00:08<00:00,  1.39it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.56s/it]
#                    all        102        116      0.804      0.854      0.863      0.479
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       58/99      12.6G    0.03253    0.01484   0.005131         52        640: 100% 12/12 [00:08<00:00,  1.34it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.28s/it]
#                    all        102        116      0.915      0.849      0.901      0.513
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       59/99      12.6G    0.02964     0.0134   0.004329         38        640: 100% 12/12 [00:08<00:00,  1.39it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.42s/it]
#                    all        102        116      0.873       0.82      0.875      0.481
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       60/99      12.6G    0.03016    0.01415    0.00404         49        640: 100% 12/12 [00:08<00:00,  1.36it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.43s/it]
#                    all        102        116      0.844      0.793      0.846      0.436
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       61/99      12.6G    0.03015     0.0143   0.003854         44        640: 100% 12/12 [00:08<00:00,  1.36it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.56s/it]
#                    all        102        116      0.865       0.85      0.878      0.481
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       62/99      12.6G    0.03024    0.01434   0.004164         41        640: 100% 12/12 [00:08<00:00,  1.37it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.49s/it]
#                    all        102        116      0.889       0.83      0.879      0.496
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       63/99      12.6G    0.03144    0.01452   0.004002         57        640: 100% 12/12 [00:08<00:00,  1.35it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.50s/it]
#                    all        102        116      0.817      0.843      0.885      0.498
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       64/99      12.6G    0.02885    0.01413   0.005509         33        640: 100% 12/12 [00:09<00:00,  1.31it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.28s/it]
#                    all        102        116      0.878      0.794      0.862      0.498
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       65/99      12.6G    0.02819    0.01384   0.004533         40        640: 100% 12/12 [00:08<00:00,  1.38it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.51s/it]
#                    all        102        116      0.838      0.887      0.888      0.506
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       66/99      12.6G    0.03001    0.01453   0.003101         52        640: 100% 12/12 [00:08<00:00,  1.34it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.59s/it]
#                    all        102        116      0.887      0.833      0.896      0.506
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       67/99      12.6G    0.02791     0.0137   0.003828         47        640: 100% 12/12 [00:08<00:00,  1.39it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.45s/it]
#                    all        102        116      0.902      0.822      0.902      0.537
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       68/99      12.6G    0.02695    0.01361     0.0033         39        640: 100% 12/12 [00:08<00:00,  1.33it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.47s/it]
#                    all        102        116       0.92      0.863      0.889      0.532
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       69/99      12.6G    0.02658    0.01361   0.006943         50        640: 100% 12/12 [00:08<00:00,  1.35it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.36s/it]
#                    all        102        116      0.919      0.845       0.91      0.548
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       70/99      12.6G    0.02771    0.01348   0.003235         38        640: 100% 12/12 [00:08<00:00,  1.36it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.51s/it]
#                    all        102        116      0.875      0.907      0.919      0.537
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       71/99      12.6G    0.02825    0.01364   0.003444         50        640: 100% 12/12 [00:08<00:00,  1.36it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.54s/it]
#                    all        102        116      0.894      0.828      0.876      0.501
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       72/99      12.6G     0.0251    0.01291   0.004002         52        640: 100% 12/12 [00:08<00:00,  1.38it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.54s/it]
#                    all        102        116      0.951      0.788      0.897      0.515
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       73/99      12.6G    0.02694    0.01336   0.003249         45        640: 100% 12/12 [00:08<00:00,  1.34it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.45s/it]
#                    all        102        116      0.884      0.874      0.902      0.493
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       74/99      12.6G    0.02703    0.01331    0.00581         44        640: 100% 12/12 [00:08<00:00,  1.37it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.68s/it]
#                    all        102        116       0.86      0.852      0.894      0.483
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       75/99      12.6G    0.02466    0.01337   0.002898         45        640: 100% 12/12 [00:08<00:00,  1.37it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.37s/it]
#                    all        102        116      0.876      0.848      0.893       0.51
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       76/99      12.6G    0.02564    0.01291   0.002845         38        640: 100% 12/12 [00:08<00:00,  1.36it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.46s/it]
#                    all        102        116      0.874      0.868      0.882      0.513
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       77/99      12.6G    0.02883    0.01299   0.004438         50        640: 100% 12/12 [00:08<00:00,  1.35it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.40s/it]
#                    all        102        116       0.86      0.823      0.879      0.511
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       78/99      12.6G    0.02737    0.01349   0.003148         43        640: 100% 12/12 [00:08<00:00,  1.37it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.50s/it]
#                    all        102        116      0.818      0.851      0.855      0.514
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       79/99      12.6G    0.02714    0.01294   0.003751         45        640: 100% 12/12 [00:08<00:00,  1.35it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.33s/it]
#                    all        102        116      0.874      0.805       0.86      0.473
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       80/99      12.6G    0.02299    0.01279   0.003066         41        640: 100% 12/12 [00:08<00:00,  1.36it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.40s/it]
#                    all        102        116      0.893      0.872      0.898      0.515
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       81/99      12.6G    0.02656    0.01311   0.004454         40        640: 100% 12/12 [00:08<00:00,  1.35it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.53s/it]
#                    all        102        116      0.872      0.883      0.896        0.5
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       82/99      12.6G    0.02676    0.01277   0.006641         44        640: 100% 12/12 [00:08<00:00,  1.36it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.40s/it]
#                    all        102        116      0.906      0.865      0.911      0.532
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       83/99      12.6G    0.02549    0.01239   0.002815         55        640: 100% 12/12 [00:08<00:00,  1.35it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.68s/it]
#                    all        102        116      0.868      0.842      0.887      0.534
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       84/99      12.6G    0.02419    0.01247   0.002968         38        640: 100% 12/12 [00:08<00:00,  1.36it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.39s/it]
#                    all        102        116      0.874      0.875      0.898      0.541
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       85/99      12.6G    0.02506    0.01245   0.002615         46        640: 100% 12/12 [00:08<00:00,  1.34it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.40s/it]
#                    all        102        116      0.875      0.882      0.892      0.539
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       86/99      12.6G    0.02442    0.01324   0.003694         51        640: 100% 12/12 [00:08<00:00,  1.36it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.58s/it]
#                    all        102        116      0.876      0.864       0.91      0.529
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       87/99      12.6G    0.02488    0.01276   0.003838         50        640: 100% 12/12 [00:08<00:00,  1.36it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.48s/it]
#                    all        102        116      0.936       0.85       0.92      0.533
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       88/99      12.6G    0.02234    0.01249    0.00275         54        640: 100% 12/12 [00:08<00:00,  1.37it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.42s/it]
#                    all        102        116      0.937      0.839      0.914      0.509
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       89/99      12.6G    0.02712    0.01372   0.002575         59        640: 100% 12/12 [00:08<00:00,  1.37it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.44s/it]
#                    all        102        116      0.871      0.884       0.89      0.505
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       90/99      12.6G    0.02287    0.01239   0.002468         45        640: 100% 12/12 [00:08<00:00,  1.38it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.56s/it]
#                    all        102        116      0.905      0.851      0.902      0.525
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       91/99      12.6G    0.02204    0.01207   0.003345         44        640: 100% 12/12 [00:08<00:00,  1.35it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.36s/it]
#                    all        102        116      0.919      0.883      0.913      0.523
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       92/99      12.6G    0.02188    0.01216   0.002139         40        640: 100% 12/12 [00:08<00:00,  1.39it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.63s/it]
#                    all        102        116      0.924      0.838      0.903      0.527
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       93/99      12.6G    0.02307    0.01241   0.002034         52        640: 100% 12/12 [00:08<00:00,  1.36it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.60s/it]
#                    all        102        116      0.869      0.872        0.9       0.52
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       94/99      12.6G    0.02319    0.01231   0.003917         40        640: 100% 12/12 [00:08<00:00,  1.37it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.47s/it]
#                    all        102        116      0.867      0.822      0.876      0.502
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       95/99      12.6G    0.02237    0.01207   0.005035         41        640: 100% 12/12 [00:08<00:00,  1.37it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.60s/it]
#                    all        102        116      0.917      0.836      0.899      0.518
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       96/99      12.6G    0.02202    0.01222   0.002423         53        640: 100% 12/12 [00:08<00:00,  1.37it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.49s/it]
#                    all        102        116      0.928       0.85      0.909      0.526
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       97/99      12.6G     0.0216    0.01156   0.003734         37        640: 100% 12/12 [00:08<00:00,  1.36it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.37s/it]
#                    all        102        116      0.928      0.857      0.913      0.531
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       98/99      12.6G    0.02069    0.01171   0.002147         46        640: 100% 12/12 [00:08<00:00,  1.36it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.41s/it]
#                    all        102        116      0.919      0.882      0.915      0.526
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       99/99      12.6G    0.01861    0.01133   0.001655         38        640: 100% 12/12 [00:08<00:00,  1.35it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.44s/it]
#                    all        102        116      0.905      0.891      0.916      0.538
#
# 100 epochs completed in 0.303 hours.
# Optimizer stripped from runs/train/exp/weights/last.pt, 14.5MB
# Optimizer stripped from runs/train/exp/weights/best.pt, 14.5MB
#
# Validating runs/train/exp/weights/best.pt...
# Fusing layers...
# Model summary: 157 layers, 7020913 parameters, 0 gradients, 15.8 GFLOPs
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.09s/it]
#                    all        102        116      0.918      0.845       0.91      0.548
#                    Car        102         26      0.975      0.962      0.968      0.758
#                 Cattle        102         33      0.866      0.818      0.855      0.491
#                    Dog        102         27      0.914      0.852      0.935      0.462
#                 People        102         30      0.918      0.749       0.88      0.482
# Results saved to runs/train/exp

# %%
# %cp -r /content/yolov5/runs/train /content/gdrive/MyDrive/

# %%
# !python detect.py --weights runs/train/exp/weights/best.pt --img 416 --conf 0.1 --source {dataset.location}/test/images
# Out:
# detect: weights=['runs/train/exp/weights/best.pt'], source=/content/yolov5/Projeto-Detecção--1/test/images, data=data/coco128.yaml, imgsz=[416, 416], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v6.2-226-gfde7758 Python-3.7.15 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7020913 parameters, 0 gradients, 15.8 GFLOPs
# image 1/4 /content/yolov5/Projeto-Detecção--1/test/images/DOG--70-_jpg.rf.ea6f57a1f9792822e0fb995b8cfc944b.jpg: 416x416 1 Dog, 8.0ms
# image 2/4 /content/yolov5/Projeto-Detecção--1/test/images/DOG--91-_jpg.rf.9194fd9ba031c81ab7ab84eed34cf4ac.jpg: 416x416 1 Dog, 8.0ms
# image 3/4 /content/yolov5/Projeto-Detecção--1/test/images/DOG--99-_png.rf.556d5c38c0b63b50c27d5cbea9345466.jpg: 416x416 1 Dog, 8.0ms
# image 4/4 /content/yolov5/Projeto-Detecção--1/test/images/Screenshot_41_png.rf.cd9dfd20630f5c07389e3cd0e7b2e3ab.jpg: 416x416 1 Car, 8.0ms
# Speed: 0.3ms pre-process, 8.0ms inference, 1.0ms NMS per image at shape (1, 3, 416, 416)
# Results saved to runs/detect/exp

# %%
#display inference on ALL test images

import glob
from IPython.display import Image, display

for imageName in glob.glob('/content/yolov5/runs/detect/exp/*.jpg'): #assuming JPG
    display(Image(filename=imageName))
    print("\n")

# %% [markdown]
# # Conclusion and Next Steps
#
# Congratulations! You've trained a custom YOLOv5 model to recognize your custom objects.
#
# To improve you model's performance, we recommend first interating on your datasets coverage and quality. See this guide for [model performance improvement](https://github.com/ultralytics/yolov5/wiki/Tips-for-Best-Training-Results).
#
# To deploy your model to an application, see this guide on [exporting your model to deployment destinations](https://github.com/ultralytics/yolov5/issues/251).
#
# Once your model is in production, you will want to continually iterate and improve on your dataset and model via [active learning](https://blog.roboflow.com/what-is-active-learning/).

# %%
#export your model's weights for future use
from google.colab import files
files.download('./runs/train/exp/weights/best.pt')
